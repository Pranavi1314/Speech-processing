# %%
pip install librosa
# Out:
# ...
#   Obtaining dependency information for librosa from https://files.pythonhosted.org/packages/e2/a2/4f639c1168d7aada749a896afb4892a831e2041bebdcf636aebfe9e86556/librosa-0.10.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for audioread>=2.1.9 from https://files.pythonhosted.org/packages/57/8d/30aa32745af16af0a9a650115fbe81bde7c610ed5c21b381fca0196f3a7f/audioread-3.0.1-py3-none-any.whl.metadata
# ...
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      - -------------------------------------- 0.0/1.0 MB 1.9 MB/s eta 0:00:01
#      ---- ----------------------------------- 0.1/1.0 MB 1.3 MB/s eta 0:00:01
#      ------ --------------------------------- 0.2/1.0 MB 1.3 MB/s eta 0:00:01
#      ----------- ---------------------------- 0.3/1.0 MB 1.8 MB/s eta 0:00:01
#      ------------- -------------------------- 0.3/1.0 MB 1.6 MB/s eta 0:00:01
#      --------------- ------------------------ 0.4/1.0 MB 1.5 MB/s eta 0:00:01
# ...

# %%
import librosa

# %%
y,sr = librosa.load(r"C:\Users\HP\Downloads\speech processing.mp3")

# %%
librosa.display.waveshow(y)

# %%
import librosa.display
from IPython.display import Audio
y,sr = librosa.load(r"C:\Users\HP\Downloads\speech processing.mp3", sr = 10000, duration = 2.75 , offset = 0.2)
Audio(data = y, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(y)

# %%
import numpy as np
y,sr = librosa.load(r"C:\Users\HP\Downloads\speech processing.mp3", sr = 10000, duration = 2.0 , offset = 0.5)
audio = np.flip(y)
Audio(data = audio, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveshow(audio)
